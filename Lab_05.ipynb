# %%
#1.Write a Python program to sum all the items in a list. 
a=[13,43,45,45,63]
b=0
for i in a:
    b=b+i
print("addition of all the elmenets is :",b)
# Out:
# addition of all the elmenets is : 209

# %%
#2.Write a Python program to multiplies all the items in a list. 
a=[14,85,62,23,47]
b=1
for i in a:
    b*=i
print("multiplication of all the elmenets is :",b)
# Out:
# multiplication of all the elmenets is : 79756180

# %%
#3.Write a Python program to get the largest number from a list
a=[35,46,52,10]
b=1
for i in a:
    if i>b:
        b=i
print("largest element is:",b)
# Out:
# largest element is: 52

# %%
#4.Write a Python program to get the smallest number from list. 
a=[12,3,35,45,56]
b=a[0]
for i in a:
    if i<b:
        b=i
print("smallest element is:",b)
# Out:
# smallest element is: 3

# %%
#5.Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings 
#Sample List : ['abc', 'xyz', 'aba', '1221']. Expected Result : 2
a=["abc","xyz","aba",'1221']
c=0
for i in range(0,len(a)):
    b=a[i]
    if len(b)>=3 and b[0]==b[-1]:
        c=c+1
print("Required output = ",c)
# Out:
# Required output =  2

# %%
# 6. Write a Python program to get a list, sorted in increasing order by the last element in each tuple from a given list of non-empty tuples.  
a= [(6, 4), (4, 10), (5, 2), (7, 3), (1, 2)]
for i in range(0,len(a)):
    for j in range(i,len(a)-1):
        if a[j][-1]>a[j+1][-1]:
            a[j],a[j+1]=a[j+1],a[j]
print(a)
# Out:
# [(6, 4), (5, 2), (1, 2), (7, 3), (4, 10)]

# %%
#7.Write a Python program to remove duplicates from a list.
a=[100,192,192,103,184,104,103,23,29,43,23]
b=[]
for i in a:
    if i not in b:
        b.append(i)
print(b)
# Out:
# [100, 192, 103, 184, 104, 23, 29, 43]

# %%
#10.Write a Python program to find the list of words that are longer than n from a given list of words.
s=int(input("Enter size :"))
a=["Adnan","Dhruv","Jatin","Jai","Hardik","Bhaskar"]
b=[]
for i in a:
    if len(i)>s:
        b.append(i)
print(b)
# Out:
# Enter size :4
# ['Adnan', 'Dhruv', 'Jatin', 'Hardik', 'Bhaskar']

# %%
#11.Write a Python function that takes two lists and returns True if they have at least one common member.  
a=[1,5,3,8,23,1]
b=[2,4,6,7,9,12]
for i in a:
    if i in b:
        print("True")
        break
else:
    print("Not common")
# Out:
# Not common

# %%
# 12. Write a Python program to print a specified list after removing the 0th, 4th and 5th elements
a=['Herbs', 'Trees', 'Bushes', 'Grass', 'Trunk', 'Climbers']
del a[0] 
del a[3]
del a[3]
print(a)
# Out:
# ['Trees', 'Bushes', 'Grass']
